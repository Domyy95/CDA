# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt


data = pd.read_csv('Private_Or_Not/dataSet_2.csv')
data
# Out:
#      Unnamed: 0  Unnamed: 0.1                                 Instituto  \
# 0             0             0                 CENTRE PRIVAT LA PURÍSIMA
# 1             1             1                          IES REI EN JAUME
# 2             2             2                      IES JOSÉ MARÍA PARRA
# 3             3             3  CENTRE PRIVAT NUESTRA SEÑORA DE LA SALUD
# 4             4             4                    IES SANT VICENT FERRER
# 5             5             5                      IES BERNAT GUINOVART
# 6             6             6                          IES FRANCESC GIL
# 7             7             7            CENTRE PRIVAT MARÍA INMACULADA
# 8             8             8        CENTRE PRIVAT SAN ANTONIO DE PADUA
# 9             9             9                  IES RICARDO MARÍN IBÁNEZ
# 10           10            10         CENTRO PRIVADO COLEGIO DE LEVANTE
# 11           11            11           CENTRE PRIVAT ESCOLÀPIES GANDIA
# ...

# %%
data['Media PAU'].groupby(data['Localidad']).describe()
# Out:
#                          count      mean       std  min    25%   50%    75%  \
# Localidad
# ADEMUZ                     1.0  6.700000       NaN  6.7  6.700  6.70  6.700
# ALACANT                   32.0  5.925000  0.619052  4.1  5.675  6.00  6.325
# ALAQUÀS                    3.0  6.200000  0.000000  6.2  6.200  6.20  6.200
# ALBAIDA                    1.0  6.400000       NaN  6.4  6.400  6.40  6.400
# ALBAL                      1.0  6.200000       NaN  6.2  6.200  6.20  6.200
# ALBALAT DE LA RIBERA       1.0  5.600000       NaN  5.6  5.600  5.60  5.600
# ALBATERA                   1.0  6.600000       NaN  6.6  6.600  6.60  6.600
# ALBERIC                    1.0  6.500000       NaN  6.5  6.500  6.50  6.500
# ALBORAIA                   2.0  6.150000  0.777817  5.6  5.875  6.15  6.425
# ALCALÀ DE XIVERT           1.0  5.900000       NaN  5.9  5.900  5.90  5.900
# ALCOI                      5.0  6.500000  0.291548  6.2  6.300  6.40  6.700
# ...
