# %%
import pandas as pd
import numpy as np

data = pd.read_csv('income_per_section/dataSet_3.csv',index_col=0)
dataprivate = pd.read_csv('Private_Or_Not/dataSet_2.csv')
                                                
# Data Cleaning
data['private'] = dataprivate.private
data
# Out:
#      Unnamed: 0.1                                 Instituto  \
# 0               0                 CENTRE PRIVAT LA PURÍSIMA
# 1               1                          IES REI EN JAUME
# 2               2                      IES JOSÉ MARÍA PARRA
# 3               3  CENTRE PRIVAT NUESTRA SEÑORA DE LA SALUD
# 4               4                    IES SANT VICENT FERRER
# ..            ...                                       ...
# 456           457                             ES L'ALLUSSER
# 457           458         CENTRO PRIVADO SAN ALBERTO MAGNO
# 458           459                         IES MARÍA BLASCO
# 459           460                   CENTRE PRIVAT EL VALLE
# 460           461     CENTRE PRIVAT ÁNGEL DE LA GUARDA III
#
#                    Localidad  Presentados  Aptos  Media Expediente  Media PAU  \
# 0                     ALZIRA           34     34               7.9        6.6
# 1                     ALZIRA           59     56               7.6        6.2
# ...

# %%
data = data.dropna()
data = data.drop(columns = 'coordinate')
data = data.drop(columns = 'Presentados')
data = data.drop(columns = 'Aptos')
data = data.drop(columns = 'lat')
data = data.drop(columns = 'long')
data
# Out:
#      Unnamed: 0.1                                     Instituto  \
# 0               0                     CENTRE PRIVAT LA PURÍSIMA
# 1               1                              IES REI EN JAUME
# 2               2                          IES JOSÉ MARÍA PARRA
# 3               3      CENTRE PRIVAT NUESTRA SEÑORA DE LA SALUD
# 4               4                        IES SANT VICENT FERRER
# ..            ...                                           ...
# 240           241                  IES RASCANYA-ANTONIO CAÑUELO
# 241           242  CENTRE ESPECÍFIC D'EDUCACIÓ A DISTÀNCIA CEED
# 242           243                 IES MARÍA CARBONELL I SÁNCHEZ
# 243           244               IES DE SAN ANTONIO DE BENAGÉBER
# 245           246                  CENTRE PRIVAT CUMBRES SCHOOL
#
#                   Localidad  Media Expediente  Media PAU  NumBib 2 km  \
# 0                    ALZIRA               7.9        6.6            0
# ...

# %%
data[['Media Expediente','Media PAU','NumBib 2 km','NumBib 5 km','NumBib 8 km','NumBib 10 km','income','private']].corr(method="kendall")
# Out:
#                   Media Expediente  Media PAU  NumBib 2 km  NumBib 5 km  \
# Media Expediente          1.000000   0.373428    -0.041423    -0.049262
# Media PAU                 0.373428   1.000000     0.059806     0.072667
# NumBib 2 km              -0.041423   0.059806     1.000000     0.789839
# NumBib 5 km              -0.049262   0.072667     0.789839     1.000000
# NumBib 8 km              -0.046825   0.062076     0.681658     0.823699
# NumBib 10 km             -0.046663   0.043815     0.625300     0.755935
# income                    0.032961   0.135533     0.227223     0.249546
# private                   0.070004   0.109077     0.235951     0.247557
#
#                   NumBib 8 km  NumBib 10 km    income   private
# Media Expediente    -0.046825     -0.046663  0.032961  0.070004
# Media PAU            0.062076      0.043815  0.135533  0.109077
# NumBib 2 km          0.681658      0.625300  0.227223  0.235951
# ...
