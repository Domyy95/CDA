# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

libraries = pd.read_csv('directorio-de-bibliotecas-valencianas.csv', encoding='ISO-8859-1', sep=';')

libraries.head()
# Out:
#    COD_PROVINCIA NOM_PROVINCIA  COD_MUNICIPIO                          TIPO  \
# 0              3      ALICANTE             10            AGENCIA DE LECTURA
# 1              3      ALICANTE            101  BIBLIOTECA PUBLICA MUNICIPAL
# 2              3      ALICANTE            102  BIBLIOTECA PUBLICA MUNICIPAL
# 3              3      ALICANTE            104  BIBLIOTECA PUBLICA MUNICIPAL
# 4              3      ALICANTE            104  BIBLIOTECA PUBLICA MUNICIPAL
#
#                                               NOMBRE  \
# 0                       AGENCIA DE LECTURA  ALFAFARA
# 1            BIBLIOTECA PUBLICA MUNICIPAL  PEDREGUER
# 2                 BIBLIOTECA PUBLICA MUNICIPAL  PEGO
# 3  BIBLIOTECA PUBLICA MUNICIPAL POETA ENRIQUE AMA...
# 4  BIBLIOTECA PUBLICA MUNICIPAL POETA PACO MOLLA ...
#
#                                 DIRECCION  COD_POSTAL              TELEFONO  \
# 0      CALLE SERRA DE MARIOLA Nº 1 PISO 1  , CP 03838   TELF.965510082 AYTO
# ...

# %%
#Address to Coordinates (Google Maps)
import googlemaps
KEY = 'AIzaSyDIOaMgv0Jr4xIK5N9FOSLWYAQXZbXcy4Y'
gmaps = googlemaps.Client(key=KEY)
tqdm.pandas()

def get_coordinates(address):
    city = 'Comunidad Valenciana, Spain'
    geocode_result = gmaps.geocode(str(address) +' '+ city)
    if len(geocode_result) > 0:
        return list(geocode_result[0]['geometry']['location'].values())
    else:
        return [np.NaN, np.NaN]
    
coordinates = libraries['DIRECCION'].progress_apply(lambda x: pd.Series(get_coordinates(x), index=['LATITUDE', 'LONGITUDE']))
libraries = pd.concat([libraries[:], coordinates[:]], axis="columns")

libraries.to_csv('Libraries_withCoordinates.csv')
# Out:
# C:\Users\domyd\Miniconda3\lib\site-packages\tqdm\std.py:651: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 684/684 [05:24<00:00,  2.11it/s]

# %%
coordinates
# Out:
#       LATITUDE  LONGITUDE
# 0    38.772550  -0.555057
# 1    38.795328   0.033273
# 2    39.201187  -0.309947
# 3    39.484011  -0.753281
# 4    38.419791  -0.392752
# ..         ...        ...
# 679  39.496745  -0.465484
# 680  39.401623  -0.404281
# 681  39.567356  -1.207533
# 682  39.465581  -0.381462
# 683  38.804634  -0.159713
#
# [684 rows x 2 columns]

# %%
coordinates.to_csv('LibrariesCoordinates.csv')
