# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
df = pd.read_csv('resumen-de-escolarizacion---2017-2018.csv',encoding = "ISO-8859-1",sep=';')
df
# Out:
#        CURSO_ACAD  COD_CENTRO                           NOM_CENTRO REG_JUR  \
# 0            2018     3000047                       CEIP LA RAMBLA     PUB
# 1            2018     3000047                       CEIP LA RAMBLA     PUB
# 2            2018     3000047                       CEIP LA RAMBLA     PUB
# 3            2018     3000047                       CEIP LA RAMBLA     PUB
# 4            2018     3000047                       CEIP LA RAMBLA     PUB
# ...           ...         ...                                  ...     ...
# 19588        2018    46035604          CEIP MARIANO JORNET PERALES     PUB
# 19589        2018    46035604          CEIP MARIANO JORNET PERALES     PUB
# 19590        2018    46035604          CEIP MARIANO JORNET PERALES     PUB
# 19591        2018    46035604          CEIP MARIANO JORNET PERALES     PUB
# 19592        2018    46036037  EI 1ER CICLE MESTRA MARÍA DE MAEZTU     PUB
#
# ...

# %%
df.DESC_ENSE_ES.unique()
# Out:
# array(['EDUCACIÓN INFANTIL', 'EDUCACIÓN PRIMARIA', 'EDUCACIÓN ESPECIAL',
#        'EDUCACIÓN SECUNDARIA OBLIGATORIA', 'BACHILLERATO',
#        'ENSEÑANZA ARTÍSTICA PROFESIONAL DE DANZA'], dtype=object)

# %%
df.DESC_TIPO_VA.unique()
# Out:
# array(['PÚBLIC', 'CONCERTAT'], dtype=object)

# %%
bac = df[df.DESC_ENSE_ES == 'BACHILLERATO']
bac
# Out:
#        CURSO_ACAD  COD_CENTRO                       NOM_CENTRO REG_JUR  \
# 129          2018     3000394                 IES PARE VITORIA     PUB
# 130          2018     3000394                 IES PARE VITORIA     PUB
# 131          2018     3000394                 IES PARE VITORIA     PUB
# 132          2018     3000394                 IES PARE VITORIA     PUB
# 133          2018     3000394                 IES PARE VITORIA     PUB
# ...           ...         ...                              ...     ...
# 19233        2018    46026779                IES ANDREU ALFARO     PUB
# 19426        2018    46029586  IES DE SAN ANTONIO DE BENAGÉBER     PUB
# 19427        2018    46029586  IES DE SAN ANTONIO DE BENAGÉBER     PUB
# 19428        2018    46029586  IES DE SAN ANTONIO DE BENAGÉBER     PUB
# 19429        2018    46029586  IES DE SAN ANTONIO DE BENAGÉBER     PUB
#
#       COD_TIPO DESC_TIPO_ES DESC_TIPO_VA             DIRECCION  \
# ...

# %%
bac[(bac.NOM_CENTRO == 'CENTRE PRIVAT LA PURÍSIMA') & (bac.LOCALIDAD == 'ALZIRA')]
# Out:
#       CURSO_ACAD  COD_CENTRO                 NOM_CENTRO REG_JUR COD_TIPO  \
# 9426        2018    46000602  CENTRE PRIVAT LA PURÍSIMA     PRI        C
# 9427        2018    46000602  CENTRE PRIVAT LA PURÍSIMA     PRI        C
# 9428        2018    46000602  CENTRE PRIVAT LA PURÍSIMA     PRI        C
# 9429        2018    46000602  CENTRE PRIVAT LA PURÍSIMA     PRI        C
#
#      DESC_TIPO_ES DESC_TIPO_VA DIRECCION LOCALIDAD  COD_MUN  ... COD_PROV  \
# 9426   CONCERTADO    CONCERTAT  RAMBLA 2    ALZIRA       17  ...       46
# 9427   CONCERTADO    CONCERTAT  RAMBLA 2    ALZIRA       17  ...       46
# 9428   CONCERTADO    CONCERTAT  RAMBLA 2    ALZIRA       17  ...       46
# 9429   CONCERTADO    CONCERTAT  RAMBLA 2    ALZIRA       17  ...       46
#
#       NOM_PROV_ES NOM_PROV_VA COD_ENSE  DESC_ENSE_ES DESC_ENSE_VA COD_CURSO  \
# 9426     VALENCIA    VALÈNCIA        4  BACHILLERATO  BATXILLERAT      1BAC
# ...

# %%
dataschool = pd.read_csv('../Grades/dataSet.csv')
dataschool
# Out:
#      Unnamed: 0                                 Instituto  \
# 0             0                 CENTRE PRIVAT LA PURÍSIMA
# 1             1                          IES REI EN JAUME
# 2             2                      IES JOSÉ MARÍA PARRA
# 3             3  CENTRE PRIVAT NUESTRA SEÑORA DE LA SALUD
# 4             4                    IES SANT VICENT FERRER
# ..          ...                                       ...
# 456         457                             ES L'ALLUSSER
# 457         458         CENTRO PRIVADO SAN ALBERTO MAGNO
# 458         459                         IES MARÍA BLASCO
# 459         460                   CENTRE PRIVAT EL VALLE
# 460         461     CENTRE PRIVAT ÁNGEL DE LA GUARDA III
#
#                    Localidad  Presentados  Aptos  Media Expediente  Media PAU  \
# 0                     ALZIRA           34     34               7.9        6.6
# 1                     ALZIRA           59     56               7.6        6.2
# ...

# %%
def isPrivate(institute,localidad):
    p = bac[(bac.NOM_CENTRO == institute) & (bac.LOCALIDAD == localidad)]
    p = p['DESC_TIPO_ES']
    if(p == 'CONCERTAT'):
        return True 

# I set True if the school is private, false if not 
private = []
for school in dataschool.itertuples():
    private.append(isPrivate(school.Instituto,school.Localidad))

df['private']=private
