# %%
import pandas as pd
import numpy as np

data = pd.read_csv('income_per_section/dataSet_3.csv')
data
# Out:
#      Unnamed: 0  Unnamed: 0.1                                 Instituto  \
# 0             0             0                 CENTRE PRIVAT LA PURÍSIMA
# 1             1             1                          IES REI EN JAUME
# 2             2             2                      IES JOSÉ MARÍA PARRA
# 3             3             3  CENTRE PRIVAT NUESTRA SEÑORA DE LA SALUD
# 4             4             4                    IES SANT VICENT FERRER
# ..          ...           ...                                       ...
# 456         456           457                             ES L'ALLUSSER
# 457         457           458         CENTRO PRIVADO SAN ALBERTO MAGNO
# 458         458           459                         IES MARÍA BLASCO
# 459         459           460                   CENTRE PRIVAT EL VALLE
# 460         460           461     CENTRE PRIVAT ÁNGEL DE LA GUARDA III
#
#                    Localidad  Presentados  Aptos  Media Expediente  Media PAU  \
# ...

# %%
# I take only the data with an income data
data = data.dropna()
data
# Out:
#      Unnamed: 0  Unnamed: 0.1                                     Instituto  \
# 0             0             0                     CENTRE PRIVAT LA PURÍSIMA
# 1             1             1                              IES REI EN JAUME
# 2             2             2                          IES JOSÉ MARÍA PARRA
# 3             3             3      CENTRE PRIVAT NUESTRA SEÑORA DE LA SALUD
# 4             4             4                        IES SANT VICENT FERRER
# ..          ...           ...                                           ...
# 240         240           241                  IES RASCANYA-ANTONIO CAÑUELO
# 241         241           242  CENTRE ESPECÍFIC D'EDUCACIÓ A DISTÀNCIA CEED
# 242         242           243                 IES MARÍA CARBONELL I SÁNCHEZ
# 243         243           244               IES DE SAN ANTONIO DE BENAGÉBER
# 245         245           246                  CENTRE PRIVAT CUMBRES SCHOOL
#
# ...

# %%
data[['Media Expediente','Media PAU','income']].corr(method ='pearson')
# Out:
#                   Media Expediente  Media PAU    income
# Media Expediente          1.000000   0.558445  0.052204
# Media PAU                 0.558445   1.000000  0.192983
# income                    0.052204   0.192983  1.000000
