# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

data = pd.read_csv('Grades/dataSet.csv')
data
# Out:
#      Unnamed: 0                                 Instituto  \
# 0             0                 CENTRE PRIVAT LA PURÍSIMA
# 1             1                          IES REI EN JAUME
# 2             2                      IES JOSÉ MARÍA PARRA
# 3             3  CENTRE PRIVAT NUESTRA SEÑORA DE LA SALUD
# 4             4                    IES SANT VICENT FERRER
# ..          ...                                       ...
# 456         457                             ES L'ALLUSSER
# 457         458         CENTRO PRIVADO SAN ALBERTO MAGNO
# 458         459                         IES MARÍA BLASCO
# 459         460                   CENTRE PRIVAT EL VALLE
# 460         461     CENTRE PRIVAT ÁNGEL DE LA GUARDA III
#
#                    Localidad  Presentados  Aptos  Media Expediente  Media PAU  \
# 0                     ALZIRA           34     34               7.9        6.6
# 1                     ALZIRA           59     56               7.6        6.2
# 2                     ALZIRA           39     36               7.0        5.2
# 3                   ALGEMESÍ           30     30               8.2        7.1
# 4                   ALGEMESÍ           30     30               8.0        7.1
# ..                       ...          ...    ...               ...        ...
# 456                 MUTXAMEL           28     24               7.3        5.0
# 457         MONFORTE DEL CID            8      8               8.4        5.8
# 458  SANT VICENT DEL RASPEIG           50     49               7.5        5.5
# 459                  ALACANT           10     10               7.9        6.9
# 460                  ALACANT           38     38               7.8        6.2
#
#                           coordinate  NumBib  NumBib 2 km  NumBib 5 km  \
# 0            [39.153307, -0.4422964]       3            0            3
# 1            [39.146734, -0.4306395]       1            0            1
# 2           [39.1569694, -0.4292533]       1            0            1
# 3           [39.1827727, -0.4375332]       3            1            3
# 4           [39.1858352, -0.4375209]       3            1            3
# ..                               ...     ...          ...          ...
# 456         [38.4209557, -0.4456107]       8            1            8
# 457  [38.38134, -0.7189599999999999]       1            1            1
# 458         [38.3905117, -0.5212411]      11            3           11
# 459               [38.5793, -0.1033]       5            1            5
# 460         [38.3666306, -0.4544057]      35            1           35
#
#      NumBib 8 km  NumBib 10 km
# 0              7             7
# 1              5             7
# 2              5             7
# 3              6             9
# 4              6             9
# ..           ...           ...
# 456           15            44
# 457            3             3
# 458           42            44
# 459            9            10
# 460           40            46
#
# [461 rows x 13 columns]

# %%
data.corr(method ='pearson')
# Out:
#                   Unnamed: 0  Presentados     Aptos  Media Expediente  \
# Unnamed: 0          1.000000    -0.051361 -0.050208         -0.074439
# Presentados        -0.051361     1.000000  0.996821          0.000890
# Aptos              -0.050208     0.996821  1.000000          0.016989
# Media Expediente   -0.074439     0.000890  0.016989          1.000000
# Media PAU           0.017108     0.120513  0.163597          0.482846
# NumBib             -0.365005     0.200935  0.203135         -0.026324
# NumBib 2 km        -0.267701     0.279139  0.285972          0.008478
# NumBib 5 km        -0.365005     0.200935  0.203135         -0.026324
# NumBib 8 km        -0.435180     0.151410  0.152336         -0.024830
# NumBib 10 km       -0.468635     0.128613  0.129355          0.009191
#
#                   Media PAU    NumBib  NumBib 2 km  NumBib 5 km  NumBib 8 km  \
# Unnamed: 0         0.017108 -0.365005    -0.267701    -0.365005    -0.435180
# Presentados        0.120513  0.200935     0.279139     0.200935     0.151410
# Aptos              0.163597  0.203135     0.285972     0.203135     0.152336
# Media Expediente   0.482846 -0.026324     0.008478    -0.026324    -0.024830
# Media PAU          1.000000  0.008321     0.072162     0.008321    -0.020027
# NumBib             0.008321  1.000000     0.821377     1.000000     0.898261
# NumBib 2 km        0.072162  0.821377     1.000000     0.821377     0.677452
# NumBib 5 km        0.008321  1.000000     0.821377     1.000000     0.898261
# NumBib 8 km       -0.020027  0.898261     0.677452     0.898261     1.000000
# NumBib 10 km      -0.008851  0.829367     0.614384     0.829367     0.974784
#
#                   NumBib 10 km
# Unnamed: 0           -0.468635
# Presentados           0.128613
# Aptos                 0.129355
# Media Expediente      0.009191
# Media PAU            -0.008851
# NumBib                0.829367
# NumBib 2 km           0.614384
# NumBib 5 km           0.829367
# NumBib 8 km           0.974784
# NumBib 10 km          1.000000

# %% [markdown]
# We Want to find a correlation between the grades and the number of nearby libraries.
# That correspond to a correlation between the variable NumBib n km and Media Expediente and Media PAU

# %%
data.corr(method="kendall")
# Out:
#                   Unnamed: 0  Presentados     Aptos  Media Expediente  \
# Unnamed: 0          1.000000    -0.032143 -0.032535         -0.053944
# Presentados        -0.032143     1.000000  0.964236         -0.004247
# Aptos              -0.032535     0.964236  1.000000          0.008112
# Media Expediente   -0.053944    -0.004247  0.008112          1.000000
# Media PAU           0.008488     0.093439  0.129569          0.328687
# NumBib             -0.193871     0.139197  0.132303         -0.063405
# NumBib 2 km        -0.179236     0.187711  0.180272         -0.056775
# NumBib 5 km        -0.193871     0.139197  0.132303         -0.063405
# NumBib 8 km        -0.271443     0.106385  0.099442         -0.042994
# NumBib 10 km       -0.277841     0.084726  0.078243         -0.035333
#
#                   Media PAU    NumBib  NumBib 2 km  NumBib 5 km  NumBib 8 km  \
# Unnamed: 0         0.008488 -0.193871    -0.179236    -0.193871    -0.271443
# Presentados        0.093439  0.139197     0.187711     0.139197     0.106385
# Aptos              0.129569  0.132303     0.180272     0.132303     0.099442
# Media Expediente   0.328687 -0.063405    -0.056775    -0.063405    -0.042994
# Media PAU          1.000000 -0.054149    -0.039272    -0.054149    -0.047395
# NumBib            -0.054149  1.000000     0.747575     1.000000     0.804006
# NumBib 2 km       -0.039272  0.747575     1.000000     0.747575     0.612566
# NumBib 5 km       -0.054149  1.000000     0.747575     1.000000     0.804006
# NumBib 8 km       -0.047395  0.804006     0.612566     0.804006     1.000000
# NumBib 10 km      -0.047419  0.740116     0.560315     0.740116     0.900207
#
#                   NumBib 10 km
# Unnamed: 0           -0.277841
# Presentados           0.084726
# Aptos                 0.078243
# Media Expediente     -0.035333
# Media PAU            -0.047419
# NumBib                0.740116
# NumBib 2 km           0.560315
# NumBib 5 km           0.740116
# NumBib 8 km           0.900207
# NumBib 10 km          1.000000

# %%
data.corr(method="spearman")
# Out:
#                   Unnamed: 0  Presentados     Aptos  Media Expediente  \
# Unnamed: 0          1.000000    -0.046810 -0.047237         -0.078257
# Presentados        -0.046810     1.000000  0.995617         -0.005942
# Aptos              -0.047237     0.995617  1.000000          0.011746
# Media Expediente   -0.078257    -0.005942  0.011746          1.000000
# Media PAU           0.010881     0.130932  0.181327          0.438891
# NumBib             -0.290289     0.202064  0.191238         -0.088058
# NumBib 2 km        -0.256504     0.264046  0.253196         -0.077335
# NumBib 5 km        -0.290289     0.202064  0.191238         -0.088058
# NumBib 8 km        -0.402784     0.156562  0.146788         -0.059977
# NumBib 10 km       -0.414500     0.125407  0.115919         -0.049504
#
#                   Media PAU    NumBib  NumBib 2 km  NumBib 5 km  NumBib 8 km  \
# Unnamed: 0         0.010881 -0.290289    -0.256504    -0.290289    -0.402784
# Presentados        0.130932  0.202064     0.264046     0.202064     0.156562
# Aptos              0.181327  0.191238     0.253196     0.191238     0.146788
# Media Expediente   0.438891 -0.088058    -0.077335    -0.088058    -0.059977
# Media PAU          1.000000 -0.079603    -0.054629    -0.079603    -0.070186
# NumBib            -0.079603  1.000000     0.879062     1.000000     0.929064
# NumBib 2 km       -0.054629  0.879062     1.000000     0.879062     0.773060
# NumBib 5 km       -0.079603  1.000000     0.879062     1.000000     0.929064
# NumBib 8 km       -0.070186  0.929064     0.773060     0.929064     1.000000
# NumBib 10 km      -0.069009  0.890846     0.729883     0.890846     0.972886
#
#                   NumBib 10 km
# Unnamed: 0           -0.414500
# Presentados           0.125407
# Aptos                 0.115919
# Media Expediente     -0.049504
# Media PAU            -0.069009
# NumBib                0.890846
# NumBib 2 km           0.729883
# NumBib 5 km           0.890846
# NumBib 8 km           0.972886
# NumBib 10 km          1.000000
